# %% [markdown]
# ## Tutorial 7: Mini Cumulative Project 1: Putting It All Together
#
# For this mini project, you’ll apply everything you’ve learned so far.
# You will load a dataset, clean it, explore it, and create simple summaries using the skills from the tutorial.
#
# <b>Note: Do NOT change the given variable name, simply replace the ... with the desired output DataFrame.</b>

# %% [markdown]
# You will submit your work on [MarkUs](https://markus.teach.cs.toronto.edu/markus/).
# To submit your work:
#
# 1. Download this Jupyter notebook file to your computer: File --> Download as --> Notebook (.ipynb). Make sure the final file name is `CJH332_tutorial7.ipynb`.
# 2. Submit this file to MarkUs under the **Mini Cumulative Project 1** assignment. (See the [MarkUs Guide](https://github.com/UofT-ArtSci-TeachingLearning/CJH332-202601/blob/main/Guide/MarkUs_Guide.ipynb) for detailed instructions)
#
# All work will take place in this Jupyter notebook. When you are done, you will download this notebook and submit it to MarkUs.

# %% [markdown]
# ### Tasks
#
# 1. **Load your dataset**
#
# Load the CSV file **Assignment.csv** into a pandas DataFrame.
#
# 2. **Inspect the data**
#
# Use the `.info()` method to get an overview of the DataFrame.
#
# 3. **Clean and filter the data**
#
# Remove rows where **geneA_expression is less than 0**
#
# Rename **geneB_expression** to **geneB_exp**
#
# **task3 should be a DataFrame**
#
# 4. **Summarize your data**
#
# Use `.groupby()` + `.agg()` on the original DataFrame to group by treatment_group and compute the mean of cell_viability.
#
# **task4 should be a DataFrame**

# %% [markdown]
# **Note**: Do not delete the comments at the top of each cell
#
# *Additional Note*: In Python, there are multiple ways to achieve the same result. Feel free to explore. However, know that the default output type of various methods can vary. However you arrive at the result, ensure that final output for task3 and task4 are **DataFrames**. You can check your datatype using the <code>type()</code> function. Example: <code>type(task3)</code>.

# %%
# Write your imports here
import ...

# %%
# Your code for part 1 here
assignment = ...

# %%
# Your code for part 2 here 
...

# %%
# Your code for part 3 here
task3 = ...

# %%
# Your code for part 4 here
task4 = ...
